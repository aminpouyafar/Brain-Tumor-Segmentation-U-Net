# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import albumentations as A
from sklearn.model_selection import train_test_split
from torchvision import models
import torch.nn.functional as F

# %%
# Collect paths of all MRI and mask images
all_images = glob.glob(
    r"D:\AI Medical Imaging\Project\LGG MRI Segmentation Dataset\kaggle_3m\*\*.tif")

# %%
# Separate MRI images and tumor masks
image_paths = []
mask_paths = []

for path in all_images:
    if 'mask' in path:
        mask_paths.append(path)
    else:
        image_paths.append(path)

# %%
# Create image-mask pairs
pairs = []
for image_path in image_paths:
    mask_path = image_path.replace('.tif', '_mask.tif')
    if mask_path in mask_paths:
        pairs.append((image_path, mask_path))

# %%
# Initialize counters for tumor and non-tumor images
tumor_count = 0
no_tumor_count = 0
# Count images with and without tumor
for image_path, mask_path in pairs:
    # Read mask as grayscale image
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    # Check if the mask contains tumor pixels
    if np.count_nonzero(mask) > 0:
        tumor_count += 1
    else:
        no_tumor_count += 1

# Print the number of images with and without tumor
print("Images with tumor:", tumor_count)
print("Images without tumor:", no_tumor_count)
# Out:
# Images with tumor: 1373
# Images without tumor: 2556

# %%
# Visualize the distribution of tumor and non-tumor images
labels = ['Tumor', 'No Tumor']
counts = [tumor_count, no_tumor_count]

plt.figure(figsize=(6, 6))
plt.bar(labels, counts)

plt.title('Distribution of Tumor and Non-Tumor Images')
plt.xlabel('Class')
plt.ylabel('Number of Images')

plt.show()

# %%
# Check if all MRI images and tumor masks have the same size
image_shapes = set()
mask_shapes = set()

for image_path, mask_path in pairs:

    image = cv2.imread(image_path)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    image_shapes.add(image.shape)
    mask_shapes.add(mask.shape)

print("Image shapes:", image_shapes)
print("Mask shapes:", mask_shapes)
# Out:
# Image shapes: {(256, 256, 3)}
# Mask shapes: {(256, 256)}

# %%
# Data augmentation for training images
train_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.ShiftScaleRotate(
        shift_limit=0.05,
        scale_limit=0.05,
        rotate_limit=15,
        p=0.5
    ),
    A.RandomBrightnessContrast(
        brightness_limit=0.1,
        contrast_limit=0.1,
        p=0.3
    ),

    A.GaussNoise(
        std_range=(0.02, 0.05),
        p=0.2
    )

])

# %%
class BrainTumorDataset(Dataset):

    def __init__(self, pairs, transform=None):

        self.pairs = pairs
        self.transform = transform

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):

        image_path, mask_path = self.pairs[idx]
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        # image = image / 255.0
        # mask = mask / 255.0
        image = image.astype(np.float32) / 255.0
        mask = mask.astype(np.float32) / 255.0
        # Apply augmentation
        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented["image"]
            mask = augmented["mask"]

        image = torch.tensor(image, dtype=torch.float32)
        mask = torch.tensor(mask, dtype=torch.float32)
        image = image.permute(2, 0, 1)
        mask = mask.unsqueeze(0)

        return image, mask

# %%
# Split dataset into training and validation sets
train_pairs, val_pairs = train_test_split(
    pairs,
    test_size=0.2,
    random_state=42
)

print("Total samples:", len(pairs))
print("Training samples:", len(train_pairs))
print("Validation samples:", len(val_pairs))
# Out:
# Total samples: 3929
# Training samples: 3143
# Validation samples: 786

# %%
# Create training and validation datasets
train_dataset = BrainTumorDataset(
    train_pairs,
    transform=train_transform
)
val_dataset = BrainTumorDataset(
    val_pairs,
    transform=None
)
print("Train dataset size:", len(train_dataset))
print("Validation dataset size:", len(val_dataset))
# Out:
# Train dataset size: 3143
# Validation dataset size: 786

# %%
# Visualize a random MRI image and its mask
idx = np.random.randint(len(train_dataset))

image, mask = train_dataset[idx]

image = image.permute(1, 2, 0).numpy()
mask = mask.squeeze().numpy()

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title("MRI Image")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(mask, cmap='gray')
plt.title("Ground Truth Mask")
plt.axis("off")

plt.show()

# %%
# Create data loaders for training and validation datasets
train_loader = DataLoader(
    train_dataset,
    batch_size=8,
    shuffle=True,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=8,
    shuffle=False,
    pin_memory=True
)

# %%
# Create a double convolution block used in U-Net
class DoubleConv(nn.Module):
    # Initialize convolution layers
    def __init__(self, in_channels, out_channels):

        super().__init__()
        self.conv = nn.Sequential(

            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),

            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    # Forward pass through the block
    def forward(self, x):

        return self.conv(x)

# %%
# Create a decoder block for U-Net
class DecoderBlock(nn.Module):
    # Initialize decoder layers
    def __init__(self, in_channels, out_channels):

        super().__init__()

        self.up = nn.ConvTranspose2d(
            in_channels,
            out_channels,
            kernel_size=2,
            stride=2
        )

        self.conv = DoubleConv(
            out_channels * 2,
            out_channels
        )

    # Forward pass through decoder block
    def forward(self, x, skip):

        x = self.up(x)

        x = torch.cat([skip, x], dim=1)

        x = self.conv(x)

        return x

# %%
class ResNet34_UNet(nn.Module):

    def __init__(self, out_channels=1):

        super().__init__()

        # Load pretrained ResNet34
        resnet = models.resnet34(weights='DEFAULT')

        # Encoder
        self.initial = nn.Sequential(
            resnet.conv1,
            resnet.bn1,
            resnet.relu
        )                                   # 64 channels

        self.maxpool = resnet.maxpool

        self.encoder1 = resnet.layer1       # 64 channels
        self.encoder2 = resnet.layer2       # 128 channels
        self.encoder3 = resnet.layer3       # 256 channels
        self.encoder4 = resnet.layer4       # 512 channels

        # Bottleneck
        self.bottleneck = nn.Sequential(
            DoubleConv(512, 1024),
            nn.Dropout2d(0.3)
        )

        # Decoder
        self.decoder1 = DecoderBlock(1024, 256)# skip4:256
        self.decoder2 = DecoderBlock(256, 128) # skip3:128
        self.decoder3 = DecoderBlock(128, 64) # skip2:64

        # Final upsampling to recover original image size
        self.up_final = nn.ConvTranspose2d(64, 64, kernel_size=2, stride=2)
        self.up_final2 = nn.ConvTranspose2d(64, 64, kernel_size=2, stride=2)


        # Final segmentation layer
        self.final_conv = nn.Conv2d(64, out_channels, kernel_size=1)

    def forward(self, x):

        # Encoder
        skip1 = self.initial(x)

        x = self.maxpool(skip1)

        skip2 = self.encoder1(x)
        skip3 = self.encoder2(skip2)
        skip4 = self.encoder3(skip3)
        x = self.encoder4(skip4)

        # Bottleneck
        x = self.bottleneck(x)

        # Decoder
        x = self.decoder1(x, skip4)
        x = self.decoder2(x, skip3)
        x = self.decoder3(x, skip2)

        # Recover original resolution
        x = self.up_final(x)
        x = self.up_final2(x)
        
        # Final prediction map
        x = self.final_conv(x)

        return x

# %%
# Create the U-Net model and move it to the available device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ResNet34_UNet().to(device)
print(device)
# Out:
# cuda

# %%
# Define Dice Loss
class DiceLoss(nn.Module):

    def __init__(self):
        super().__init__()

    def forward(self, outputs, targets):

        outputs = torch.sigmoid(outputs)

        intersection = (outputs * targets).sum()

        dice = (
            2 * intersection + 1e-8
        ) / (
            outputs.sum() + targets.sum() + 1e-8
        )

        return 1 - dice
    
    # Define Focal Loss
class FocalLoss(nn.Module):

    def __init__(self, alpha=0.8, gamma=2):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, outputs, targets):

        bce = F.binary_cross_entropy_with_logits(
            outputs,
            targets,
            reduction='none'
        )

        pt = torch.exp(-bce)

        focal = self.alpha * (1 - pt) ** self.gamma * bce

        return focal.mean()


# Define loss functions
dice_loss = DiceLoss()
focal_loss = FocalLoss(alpha=0.25, gamma=2)

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-5
)

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',      # Higher Dice score indicates better performance
    factor=0.5,      # Reduce learning rate by half
    patience=2       # Reduce LR if no improvement for 2 epochs
)

# %%
#Training
def train(model, dataloader, optimizer):
    model.train()
    total_loss = 0
    for images, masks in dataloader:
        images = images.to(device)
        masks = masks.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = (
            0.5 * focal_loss(outputs, masks)
            +
            0.5 * dice_loss(outputs, masks)
        )
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(dataloader)

# Validation
def validate(model, dataloader):
    model.eval()
    total_loss = 0
    total_dice = 0
    with torch.no_grad():
        for images, masks in dataloader:
            images = images.to(device)
            masks = masks.to(device)
            outputs = model(images)
            loss = (
                0.5 * focal_loss(outputs, masks)
                +
                0.5 * dice_loss(outputs, masks)
            )
            total_loss += loss.item()
            outputs = torch.sigmoid(outputs)
            outputs = (outputs > 0.5).float()
            intersection = (outputs * masks).sum()
            dice = (
                2 * intersection + 1e-8
            ) / (
                outputs.sum() + masks.sum() + 1e-8
            )
            total_dice += dice.item()

    avg_loss = total_loss / len(dataloader)
    avg_dice = total_dice / len(dataloader)

    return avg_loss, avg_dice

train_losses = []
val_losses = []
dice_scores = []
num_epochs = 30
best_dice = 0.0
patience = 8
patience_counter = 0

for epoch in range(num_epochs):

    train_loss = train(
        model,
        train_loader,
        optimizer
    )

    val_loss, dice_score = validate(
        model,
        val_loader
    )
    
    scheduler.step(dice_score)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    dice_scores.append(dice_score)

    # Early Stopping + Save Best Model
    if dice_score > best_dice:
        best_dice = dice_score
        patience_counter = 0
        torch.save(
            model.state_dict(),
            "best_model_with_ResNet34_with_FocalLoss.pth"
        )
        print("Best model saved.")
    else:
        patience_counter += 1
    
    # Get current learning rate
    current_lr = optimizer.param_groups[0]['lr']

    print(
        f"Epoch [{epoch+1}/{num_epochs}] | "
        f"Train Loss: {train_loss:.4f} | "
        f"Val Loss: {val_loss:.4f} | "
        f"Dice: {dice_score:.4f} | "
        f"Best Dice: {best_dice:.4f} |"
        f"LR: {current_lr:.7f}"
    ) 
    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

    

# Plot training and validation losses
plt.figure(figsize=(12,5))
plt.plot(
    range(1, len(train_losses)+1),
    train_losses,
    label="Train Loss"
)
plt.plot(
    range(1, len(val_losses)+1),
    val_losses,
    label="Validation Loss"
)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid()
plt.show()

# Plot Dice Score
plt.figure(figsize=(12,5))
plt.plot(
    range(1, len(dice_scores)+1),
    dice_scores,
    label="Dice Score"
)

plt.xlabel("Epoch")
plt.ylabel("Dice")
plt.title("Validation Dice Score")
plt.ylim(0, 1)
plt.legend() 
plt.grid()
plt.tight_layout()
plt.show()

print("Training Finished")
print(f"Best Dice Score: {best_dice:.4f}")
# Out:
# Best model saved.
# Epoch [1/30] | Train Loss: 0.2873 | Val Loss: 0.1710 | Dice: 0.6812 | Best Dice: 0.6812 |LR: 0.0001000
# Best model saved.
# Epoch [2/30] | Train Loss: 0.1345 | Val Loss: 0.1444 | Dice: 0.7307 | Best Dice: 0.7307 |LR: 0.0001000
# Best model saved.
# Epoch [3/30] | Train Loss: 0.1154 | Val Loss: 0.1280 | Dice: 0.7921 | Best Dice: 0.7921 |LR: 0.0001000
# Best model saved.
# Epoch [4/30] | Train Loss: 0.1098 | Val Loss: 0.1317 | Dice: 0.7950 | Best Dice: 0.7950 |LR: 0.0001000
# Best model saved.
# Epoch [5/30] | Train Loss: 0.0978 | Val Loss: 0.1126 | Dice: 0.8334 | Best Dice: 0.8334 |LR: 0.0001000
# Epoch [6/30] | Train Loss: 0.1126 | Val Loss: 0.1180 | Dice: 0.8100 | Best Dice: 0.8334 |LR: 0.0001000
# Epoch [7/30] | Train Loss: 0.1005 | Val Loss: 0.1077 | Dice: 0.8315 | Best Dice: 0.8334 |LR: 0.0001000
# Epoch [8/30] | Train Loss: 0.0921 | Val Loss: 0.1136 | Dice: 0.8216 | Best Dice: 0.8334 |LR: 0.0000500
# Best model saved.
# Epoch [9/30] | Train Loss: 0.0793 | Val Loss: 0.1013 | Dice: 0.8435 | Best Dice: 0.8435 |LR: 0.0000500
# Epoch [10/30] | Train Loss: 0.0907 | Val Loss: 0.1091 | Dice: 0.8381 | Best Dice: 0.8435 |LR: 0.0000500
# Epoch [11/30] | Train Loss: 0.0858 | Val Loss: 0.1036 | Dice: 0.8293 | Best Dice: 0.8435 |LR: 0.0000500
# Best model saved.
# Epoch [12/30] | Train Loss: 0.0855 | Val Loss: 0.1064 | Dice: 0.8452 | Best Dice: 0.8452 |LR: 0.0000500
# Best model saved.
# Epoch [13/30] | Train Loss: 0.0813 | Val Loss: 0.1004 | Dice: 0.8556 | Best Dice: 0.8556 |LR: 0.0000500
# Epoch [14/30] | Train Loss: 0.0825 | Val Loss: 0.1081 | Dice: 0.8410 | Best Dice: 0.8556 |LR: 0.0000500
# Epoch [15/30] | Train Loss: 0.0825 | Val Loss: 0.1042 | Dice: 0.8379 | Best Dice: 0.8556 |LR: 0.0000500
# Epoch [16/30] | Train Loss: 0.0841 | Val Loss: 0.1123 | Dice: 0.8323 | Best Dice: 0.8556 |LR: 0.0000250
# Epoch [17/30] | Train Loss: 0.0726 | Val Loss: 0.1028 | Dice: 0.8494 | Best Dice: 0.8556 |LR: 0.0000250
# Epoch [18/30] | Train Loss: 0.0748 | Val Loss: 0.0970 | Dice: 0.8526 | Best Dice: 0.8556 |LR: 0.0000250
# Best model saved.
# Epoch [19/30] | Train Loss: 0.0790 | Val Loss: 0.0972 | Dice: 0.8618 | Best Dice: 0.8618 |LR: 0.0000250
# Best model saved.
# Epoch [20/30] | Train Loss: 0.0787 | Val Loss: 0.0972 | Dice: 0.8624 | Best Dice: 0.8624 |LR: 0.0000250
# Epoch [21/30] | Train Loss: 0.0738 | Val Loss: 0.0950 | Dice: 0.8468 | Best Dice: 0.8624 |LR: 0.0000250
# Best model saved.
# Epoch [22/30] | Train Loss: 0.0766 | Val Loss: 0.0950 | Dice: 0.8662 | Best Dice: 0.8662 |LR: 0.0000250
# Epoch [23/30] | Train Loss: 0.0728 | Val Loss: 0.0968 | Dice: 0.8629 | Best Dice: 0.8662 |LR: 0.0000250
# Epoch [24/30] | Train Loss: 0.0739 | Val Loss: 0.0969 | Dice: 0.8530 | Best Dice: 0.8662 |LR: 0.0000250
# Epoch [25/30] | Train Loss: 0.0760 | Val Loss: 0.0961 | Dice: 0.8542 | Best Dice: 0.8662 |LR: 0.0000125
# Best model saved.
# Epoch [26/30] | Train Loss: 0.0737 | Val Loss: 0.0934 | Dice: 0.8696 | Best Dice: 0.8696 |LR: 0.0000125
# Epoch [27/30] | Train Loss: 0.0635 | Val Loss: 0.0964 | Dice: 0.8430 | Best Dice: 0.8696 |LR: 0.0000125
# Epoch [28/30] | Train Loss: 0.0658 | Val Loss: 0.0954 | Dice: 0.8554 | Best Dice: 0.8696 |LR: 0.0000125
# Best model saved.
# Epoch [29/30] | Train Loss: 0.0682 | Val Loss: 0.0930 | Dice: 0.8699 | Best Dice: 0.8699 |LR: 0.0000125
# Best model saved.
# Epoch [30/30] | Train Loss: 0.0672 | Val Loss: 0.0921 | Dice: 0.8719 | Best Dice: 0.8719 |LR: 0.0000125
# Training Finished
# Best Dice Score: 0.8719

# %%
# Load best saved model
model.load_state_dict(torch.load("best_model_with_ResNet34_with_FocalLoss.pth", map_location=device))
model.eval()

# Select random samples from validation set
num_samples = 5
indices = np.random.choice(len(val_dataset), num_samples)

plt.figure(figsize=(12, num_samples * 4))

for i, idx in enumerate(indices):

    image, mask = val_dataset[idx]

    with torch.no_grad():
        pred = model(
            image.unsqueeze(0).to(device)
        )

        pred = torch.sigmoid(pred)
        pred = (pred > 0.5).float()

    image = image.permute(1, 2, 0).numpy()
    mask = mask.squeeze().numpy()
    pred = pred.squeeze().cpu().numpy()

    # MRI image
    plt.subplot(num_samples, 3, i * 3 + 1)
    plt.imshow(image)
    plt.title("MRI")
    plt.axis("off")

    # Ground truth
    plt.subplot(num_samples, 3, i * 3 + 2)
    plt.imshow(mask, cmap="gray")
    plt.title("Ground Truth")
    plt.axis("off")

    # Prediction
    plt.subplot(num_samples, 3, i * 3 + 3)
    plt.imshow(pred, cmap="gray")
    plt.title("Prediction")
    plt.axis("off")

plt.tight_layout()
plt.show()
